# %% [markdown]
# ## DEMO: Debugging a Broken Agent using Logs
#
# ### INTRODUCTION
# This demo illustrates how to debug a broken agent using structured logs.
# We’ll build a lightweight agent equipped with basic reasoning, simulate tool usage, and intentionally introduce failures.
#
# By analyzing the generated log file, you can trace the agent’s decisions, identify errors, and understand how logging enables observability in AI workflows.
#
# -------------------------------------------------------------
# OBJECTIVES
# -------------------------------------------------------------
# - Simulate an agent that performs reasoning steps.
# - Integrate basic tools — a pseudo Calculator and a random tool failure.
# - Introduce intentional bugs to observe failure patterns.
# - Capture reasoning and exceptions using Python’s file-based logging.
# - Use Gradio to interact with the agent in real time.
# - Analyze the log file to identify the root cause of failures.
# -------------------------------------------------------------
# ⚙️ INSTRUCTIONS TO RUN
# -------------------------------------------------------------
#
# 1️⃣ **Install dependencies:**

# %%
pip install langchain langchain-community langchain-openai gradio wikipedia
# Out:
# Requirement already satisfied: langchain in c:\users\datas\anaconda3\anaconda\lib\site-packages (0.3.25)
# Requirement already satisfied: langchain-community in c:\users\datas\anaconda3\anaconda\lib\site-packages (0.3.21)
# Requirement already satisfied: langchain-openai in c:\users\datas\anaconda3\anaconda\lib\site-packages (0.3.32)
# Requirement already satisfied: gradio in c:\users\datas\anaconda3\anaconda\lib\site-packages (6.10.0)
# Requirement already satisfied: wikipedia in c:\users\datas\anaconda3\anaconda\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (0.3.75)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (2.0.25)
# Requirement already satisfied: requests<3,>=2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (3.12.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (2.9.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-community) (2.4.3)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-openai) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.129.2)
# Requirement already satisfied: ffmpy in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (2.4.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (1.8.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (3.0.1)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydub in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.0.22)
# Requirement already satisfied: pytz>=2017.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (2023.3.post1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\datas\anaconda3\anaconda\lib\site-packages (from gradio-client==2.4.0->gradio) (2023.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from wikipedia) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: idna>=2.8 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\datas\anaconda3\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\datas\anaconda3\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.13.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.65.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\datas\anaconda3\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: colorama in c:\users\datas\anaconda3\anaconda\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: six>=1.5 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\datas\anaconda3\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2️⃣ Run the script
# It will:
#
# - Launch a Gradio interface.
# - Log all queries and errors to simple_agent_debug.log.
# - Randomly trigger failures for demonstration.
#
# 3️⃣ Try these queries:
#
# - calc 25 6
#
# - calc 78*7
#
# - hello
#
# 4️⃣ Inspect the log file
# After running a few queries, open simple_agent_debug.log.
# You’ll find detailed entries including:
#
# - Received queries
# - Tool calls and responses
# - Exceptions raised
# - Execution time per request

# %%
# =========================================================
# Simple Demo: Debugging a Broken Agent 
# =========================================================

import gradio as gr
import random
import time
from datetime import datetime

LOG_FILE = "simple_agent_debug.log"

def log_to_file(message: str, error: bool = False):
    """Directly writes to log file immediately (bypasses logging buffers)."""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    prefix = "ERROR" if error else "INFO"
    with open(LOG_FILE, "a", encoding="utf-8") as f:
        f.write(f"{timestamp} | {prefix} | {message}\n")
        f.flush()

log_to_file("Starting Simple Agent Debug Demo")

def simple_agent(query: str) -> str:
    """Simulated agent that occasionally breaks."""
    log_to_file(f"Received query: {query}")
    start = time.time()

    try:
        if "calc" in query.lower():
            # Randomly use a broken or valid tool
            tool_name = "BrokenCalculator" if random.random() < 0.4 else "Calculator"
            log_to_file(f"Trying to use tool: {tool_name}")

            if tool_name == "Calculator":
                # Parse either "calc 25 6" or "calc 78*7" safely.
                digits = [int(s) for s in query.replace("*", " ").split() if s.isdigit()]
                if len(digits) < 2:
                    raise ValueError("Please provide two numbers, for example: 'calc 25 6' or 'calc 78*7'")
                result = digits[0] * digits[1]
                log_to_file(f"Calculation successful: {result}")
                answer = f"The result is {result}"
            else:
                raise ValueError(f"Tool '{tool_name}' not found")
        else:
            answer = f"I don't know how to handle '{query}'"
            log_to_file("No valid tool found for this query")

    except Exception as e:
        log_to_file(f"Error occurred: {e}", error=True)
        answer = f"Agent failed due to: {e}"

    finally:
        elapsed = time.time() - start
        log_to_file(f"Query completed in {elapsed:.2f}s\n")

    return answer


demo = gr.Interface(
    fn=simple_agent,
    inputs=gr.Textbox(lines=2, placeholder="Try: calc 67 8 or calc 78*7"),
    outputs="text",
    title="Debugging a Broken Agent (Simple Example)",
    description="Agent occasionally fails to find tool or parse input. "
                "Open simple_agent_debug.log after each run to inspect reasoning and errors."
)

if __name__ == "__main__":
    demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
